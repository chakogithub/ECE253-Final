# %%
import numpy as np
import pywt
import cv2
import os
from skimage.metrics import peak_signal_noise_ratio, structural_similarity

# For display (optional)
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 import numpy as np
# ----> 2 import pywt
#       3 import cv2
#       4 import os
#
# File /opt/conda/lib/python3.11/site-packages/pywt/__init__.py:15
#       8 """
#       9 Discrete forward and inverse wavelet transform, stationary wavelet transform,
#      10 wavelet packets signal decomposition and reconstruction module.
#      11 """
#      13 from __future__ import division, print_function, absolute_import
# ---> 15 from ._extensions._pywt import *
#      16 from ._functions import *
#      17 from ._multilevel import *
#
# File pywt/_extensions/_pywt.pyx:1, in init pywt._extensions._pywt()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject
